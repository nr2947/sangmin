# %% [markdown]
# ## 은닉층 1개인 신경망을 이용하여
# ## 선형회귀 (Linear Regression) 구현

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime

# %matplotlib inline

# %% [markdown]
# #### training data 를 전치행렬 형태로 읽어온다
# #### 또한 제목이 있는 1행은 skip 하기 위해 skiprows=1 옵션 기술함

# %%
transposed_loaded_data = np.loadtxt('./airplane_train.csv', unpack=True, delimiter=',', skiprows=1)

print(transposed_loaded_data.shape)
# Out:
# (3, 300)

# %% [markdown]
# #### 입력데이터와 정답데이터의 관계를 파악하기 위해 그래프를 그려봄
# #### 입력이 Speed, Weight 두개이므로 입력데이터를 x1, x2 로 구분함

# %%
training_x1_data = transposed_loaded_data[0]  # 전치행렬되기 전의 Speed 열 (column)

training_x2_data = transposed_loaded_data[1]  # 전치행렬되기 전의 Weight 열 (column)

training_t_data = transposed_loaded_data[2]   # 전치행렬되기 전의 정답인 Distance 열 (column)

# %%
# 녹색(g)에 둥근점(o)으로 시각화

plt.title('training_x1_data  vs. training_t_data')
plt.xlabel('Speed to take off')
plt.ylabel('Distance')
plt.grid()
#plt.xlim(289,321) 
plt.plot(training_x1_data, training_t_data, 'go')

plt.show()

# %%
# 파란색(b)에 둥근점(o)으로 시각화

plt.title('training_x2_data  vs. training_t_data')
plt.xlabel('Airplane weight')
plt.ylabel('Distance')
plt.grid()
#plt.xlim(209, 301) 
plt.plot(training_x2_data, training_t_data, 'bo')

plt.show()

# %% [markdown]
# #### 입력값과 정답이 큰 값  (>1000) 이므로 데이터 정규화 수행

# %%
# normalize function, 0~1 값으로 정규화
def minmax_normalize(data):
    
    min_val = data.min()
    max_val = data.max()
    
    return ( data - min_val ) / ( max_val - min_val ) 

# de-normalize, 0~1 값을 실제 값으로 역 정규화
def minmax_get_denormalize(normalized_data, data_array):
    
    max_val, min_val = data_array.max(), data_array.min()
    
    denormalized_data = normalized_data * (max_val-min_val) + min_val
    
    return denormalized_data

# 데이터 정규화 후, 임의의 값을 0~1 사이의 값으로 정규화 해주는 함수
def minmax_get_normalize(data, data_array):
    
    min_val = data_array.min()
    max_val = data_array.max()
    
    return ( data - min_val ) / ( max_val - min_val )

# %%
normalized_training_x1_data = minmax_normalize(training_x1_data)

normalized_training_x2_data = minmax_normalize(training_x2_data)

normalized_training_t_data = minmax_normalize(training_t_data)

# %%
# 녹색(g)에 둥근점(o)으로 시각화

plt.title('normalized_training_x1_data  vs. normalized_training_t_data')
plt.xlabel('Speed to take off')
plt.ylabel('Distance')
plt.grid()
plt.plot(normalized_training_x1_data, normalized_training_t_data, 'go')

plt.show()

# %%
# 파란색(b)에 둥근점(o)으로 시각화

plt.title('normalized_training_x2_data  vs. normalized_training_t_data')
plt.xlabel('Airplane weight')
plt.ylabel('Distance')
plt.grid()
plt.plot(normalized_training_x2_data, normalized_training_t_data, 'bo')

plt.show()

# %%
# 학습을 위한 입력데이터, 정답데이터 구성

training_input_data_list = [ [ x1_data for x1_data in normalized_training_x1_data ],
                             [ x2_data for x2_data in normalized_training_x2_data ] ]

training_input_data = np.array(training_input_data_list).reshape(-1,2)  # 리스트 이므로 numpy 변형 후 reshape

training_target_data = normalized_training_t_data.reshape(-1,1)

print('training_input_data.shape = ', training_input_data.shape, ', training_target_data.shape = ', training_target_data.shape)

# test 저장
np.savetxt('./airplane_train_data.csv', training_input_data, delimiter=',')
np.savetxt('./airplane_target_data.csv', training_target_data, delimiter=',')
# Out:
# training_input_data.shape =  (300, 2) , training_target_data.shape =  (300, 1)

# %%
# Hyper-Parameter 최적화가 필요하나 학습데이터의 절대량이 부족하여 근사값에 한계가 있음
learning_rate = 1e-5
input_nodes = training_input_data.shape[1]  
hidden_nodes = 40
output_nodes = 1
epochs = 1

# %%
# 입력과 출력을 위한 플레이스홀더 정의
X_DATA = tf.placeholder(tf.float32, [None, input_nodes])  
T_DATA = tf.placeholder(tf.float32, [None, output_nodes])  

W2 = tf.Variable(tf.random_normal([input_nodes, hidden_nodes]))  # 은닉층 가중치 노드
b2 = tf.Variable(tf.random_normal([hidden_nodes]))               # 은닉층 바이어스 노드

W3 = tf.Variable(tf.random_normal([hidden_nodes, output_nodes])) # 출력층 가중치 노드
b3 = tf.Variable(tf.random_normal([output_nodes]))               # 출력층 바이어스 노드

# %%
# feed forward
Z2 = tf.matmul(X_DATA, W2) + b2
A2 = tf.sigmoid(Z2)

# 선형회귀이므로 출력층에서는 sigmoid 불필요
y = Z3 = tf.matmul(A2, W3) + b3  

# 선형회귀 이므로 손실함수는 MSE
loss = tf.reduce_mean(tf.square(y-T_DATA))

# %%
# GradientDescent 
optimizer = tf.train.GradientDescentOptimizer(learning_rate)

train = optimizer.minimize(loss)

# %%
with  tf.Session()  as sess:
    
    sess.run(tf.global_variables_initializer())  # 변수 노드(tf.Variable) 초기화

    start_time = datetime.now()
    
    for i in range(epochs):
    
        for step in range(100001):
      
            loss_val, _ = sess.run([loss, train], feed_dict={X_DATA: training_input_data, T_DATA: training_target_data})    
        
            if step % 1000 == 0:
                print("epochs = ", i, ", step = ", step, ", loss_val = ", loss_val)             
    
    end_time = datetime.now()
    
    print("")
    print("Elapsed Time => ", end_time-start_time)
    
    
    #######################################################################################################
    # test data 로딩
    transposed_loaded_test_data = np.loadtxt('./airplane_test.csv', unpack=True, delimiter=',', skiprows=1)
    
    
    # 테스트를 위한 입력 데이터 / 정답 데이터 분리
    test_x1_data = transposed_loaded_test_data[0]  # 전치행렬되기 전의 Speed 열 (column)

    test_x2_data = transposed_loaded_test_data[1]  # 전치행렬되기 전의 Weight 열 (column)

    test_t_data = transposed_loaded_test_data[2]   # 전치행렬되기 전의 정답인 Distance 열 (column)
    
    
    # 테스트 데이터 정규화 진행
    normalized_test_x1_data = minmax_normalize(test_x1_data)
    
    normalized_test_x2_data = minmax_normalize(test_x2_data)
    
    normalized_test_t_data = minmax_normalize(test_t_data)
    
    
    # 테스트를 위한 입력데이터, 정답데이터 구성

    test_input_data_list = [ [ x1_data for x1_data in normalized_test_x1_data ],
                             [ x2_data for x2_data in normalized_test_x2_data ] ]

    test_input_data = np.array(test_input_data_list).reshape(-1,2)  # 리스트 이므로 numpy 변형 후 reshape

    test_target_data = normalized_test_t_data.reshape(-1,1)

    print('test_input_data.shape = ', test_input_data.shape, ', test_target_data.shape = ', test_target_data.shape)
    
    
    # 테스트 데이터에 대한 예측 값, 즉 정규화된 이륙거리 예측
    normalized_predicted_distance = sess.run(y, feed_dict={X_DATA: test_input_data})
    
    # 정규값을 실제 거리로 변환함. 이때 테스트의 정규화되지 않은 정답데이터에 대해 역정규화해주어야 함
    real_predicted_distance = minmax_get_denormalize(normalized_predicted_distance, test_t_data)
    
    # 예측값과 실제값을 비교하기 위한 리스트
    #temp_list = []  # 임시리스트
    #prediction_label_list = []  # 예측값_정답 리스트
    
    #for index in range(len(test_t_data)):
        
        #temp_list.append(real_predicted_distance[index])  # 예측값 저장
        #temp_list.append(test_t_data[index])
        
        #prediction_label_list.append(temp_list)
        
        #temp_list = []
        
    
    #print("")
    #print("===========================================================")
    #print(prediction_label_list)
    
    print("===========================================================")
    for index in range(len(test_t_data)):
        
        print("prediction = ", real_predicted_distance[index], ", label = ", test_t_data[index])
# Out:
# epochs =  0 , step =  0 , loss_val =  18.689875
# epochs =  0 , step =  1000 , loss_val =  10.174454
# epochs =  0 , step =  2000 , loss_val =  5.562079
# epochs =  0 , step =  3000 , loss_val =  3.0643935
# epochs =  0 , step =  4000 , loss_val =  1.7125572
# epochs =  0 , step =  5000 , loss_val =  0.9812543
# epochs =  0 , step =  6000 , loss_val =  0.5857431
# epochs =  0 , step =  7000 , loss_val =  0.37180528
# epochs =  0 , step =  8000 , loss_val =  0.2559928
# epochs =  0 , step =  9000 , loss_val =  0.19318283
# epochs =  0 , step =  10000 , loss_val =  0.15898822
# epochs =  0 , step =  11000 , loss_val =  0.14025122
# epochs =  0 , step =  12000 , loss_val =  0.12984695
# epochs =  0 , step =  13000 , loss_val =  0.1239454
# epochs =  0 , step =  14000 , loss_val =  0.12047319
# epochs =  0 , step =  15000 , loss_val =  0.118317924
# epochs =  0 , step =  16000 , loss_val =  0.11687533
# epochs =  0 , step =  17000 , loss_val =  0.11582103
# epochs =  0 , step =  18000 , loss_val =  0.11496526
# epochs =  0 , step =  19000 , loss_val =  0.11422895
# epochs =  0 , step =  20000 , loss_val =  0.113565676
# epochs =  0 , step =  21000 , loss_val =  0.11293883
# epochs =  0 , step =  22000 , loss_val =  0.112335026
# epochs =  0 , step =  23000 , loss_val =  0.111744486
# epochs =  0 , step =  24000 , loss_val =  0.11116458
# epochs =  0 , step =  25000 , loss_val =  0.11059191
# epochs =  0 , step =  26000 , loss_val =  0.11002595
# epochs =  0 , step =  27000 , loss_val =  0.109466694
# epochs =  0 , step =  28000 , loss_val =  0.10891332
# epochs =  0 , step =  29000 , loss_val =  0.10836351
# epochs =  0 , step =  30000 , loss_val =  0.10781635
# epochs =  0 , step =  31000 , loss_val =  0.10727551
# epochs =  0 , step =  32000 , loss_val =  0.1067423
# epochs =  0 , step =  33000 , loss_val =  0.10622133
# epochs =  0 , step =  34000 , loss_val =  0.10570322
# epochs =  0 , step =  35000 , loss_val =  0.10518762
# epochs =  0 , step =  36000 , loss_val =  0.10467587
# epochs =  0 , step =  37000 , loss_val =  0.104167536
# epochs =  0 , step =  38000 , loss_val =  0.10366238
# epochs =  0 , step =  39000 , loss_val =  0.10316117
# epochs =  0 , step =  40000 , loss_val =  0.102665216
# epochs =  0 , step =  41000 , loss_val =  0.102172524
# epochs =  0 , step =  42000 , loss_val =  0.10168364
# epochs =  0 , step =  43000 , loss_val =  0.10119822
# epochs =  0 , step =  44000 , loss_val =  0.10071597
# epochs =  0 , step =  45000 , loss_val =  0.10024184
# epochs =  0 , step =  46000 , loss_val =  0.09977376
# epochs =  0 , step =  47000 , loss_val =  0.09930862
# epochs =  0 , step =  48000 , loss_val =  0.098848306
# epochs =  0 , step =  49000 , loss_val =  0.09839086
# epochs =  0 , step =  50000 , loss_val =  0.097935915
# epochs =  0 , step =  51000 , loss_val =  0.09748504
# epochs =  0 , step =  52000 , loss_val =  0.097043306
# epochs =  0 , step =  53000 , loss_val =  0.09660692
# epochs =  0 , step =  54000 , loss_val =  0.096174
# epochs =  0 , step =  55000 , loss_val =  0.09574522
# epochs =  0 , step =  56000 , loss_val =  0.09531999
# epochs =  0 , step =  57000 , loss_val =  0.09489989
# epochs =  0 , step =  58000 , loss_val =  0.09448305
# epochs =  0 , step =  59000 , loss_val =  0.09406948
# epochs =  0 , step =  60000 , loss_val =  0.093660146
# epochs =  0 , step =  61000 , loss_val =  0.093256034
# epochs =  0 , step =  62000 , loss_val =  0.092856385
# epochs =  0 , step =  63000 , loss_val =  0.09245991
# epochs =  0 , step =  64000 , loss_val =  0.092068
# epochs =  0 , step =  65000 , loss_val =  0.09168099
# epochs =  0 , step =  66000 , loss_val =  0.091296636
# epochs =  0 , step =  67000 , loss_val =  0.09091704
# epochs =  0 , step =  68000 , loss_val =  0.09053996
# epochs =  0 , step =  69000 , loss_val =  0.09016485
# epochs =  0 , step =  70000 , loss_val =  0.08979258
# epochs =  0 , step =  71000 , loss_val =  0.08942282
# epochs =  0 , step =  72000 , loss_val =  0.08905625
# epochs =  0 , step =  73000 , loss_val =  0.0886928
# epochs =  0 , step =  74000 , loss_val =  0.08833316
# epochs =  0 , step =  75000 , loss_val =  0.08797555
# epochs =  0 , step =  76000 , loss_val =  0.087625556
# epochs =  0 , step =  77000 , loss_val =  0.08727809
# epochs =  0 , step =  78000 , loss_val =  0.08693274
# epochs =  0 , step =  79000 , loss_val =  0.08658982
# epochs =  0 , step =  80000 , loss_val =  0.08624939
# epochs =  0 , step =  81000 , loss_val =  0.085912965
# epochs =  0 , step =  82000 , loss_val =  0.085578986
# epochs =  0 , step =  83000 , loss_val =  0.08524706
# epochs =  0 , step =  84000 , loss_val =  0.084916964
# epochs =  0 , step =  85000 , loss_val =  0.08458858
# epochs =  0 , step =  86000 , loss_val =  0.0842666
# epochs =  0 , step =  87000 , loss_val =  0.083948806
# epochs =  0 , step =  88000 , loss_val =  0.08363309
# epochs =  0 , step =  89000 , loss_val =  0.08331922
# epochs =  0 , step =  90000 , loss_val =  0.08300759
# epochs =  0 , step =  91000 , loss_val =  0.082698196
# epochs =  0 , step =  92000 , loss_val =  0.08239107
# epochs =  0 , step =  93000 , loss_val =  0.082087815
# epochs =  0 , step =  94000 , loss_val =  0.081787236
# epochs =  0 , step =  95000 , loss_val =  0.08148875
# epochs =  0 , step =  96000 , loss_val =  0.081192456
# epochs =  0 , step =  97000 , loss_val =  0.08089805
# epochs =  0 , step =  98000 , loss_val =  0.080604985
# epochs =  0 , step =  99000 , loss_val =  0.08031332
# epochs =  0 , step =  100000 , loss_val =  0.080023654
#
# Elapsed Time =>  0:00:59.501000
# test_input_data.shape =  (80, 2) , test_target_data.shape =  (80, 1)
# ===========================================================
# prediction =  [2054.945] , label =  2257.0
# prediction =  [2013.2194] , label =  2215.0
# prediction =  [1928.7046] , label =  2192.0
# prediction =  [1964.4714] , label =  2165.0
# prediction =  [1948.1992] , label =  2153.0
# prediction =  [2005.0618] , label =  2132.0
# prediction =  [1876.7195] , label =  2130.0
# prediction =  [1956.3394] , label =  2124.0
# prediction =  [2004.721] , label =  2110.0
# prediction =  [2003.5868] , label =  2094.0
# prediction =  [1866.3862] , label =  2083.0
# prediction =  [1950.0098] , label =  2055.0
# prediction =  [2063.5708] , label =  2043.0
# prediction =  [2038.825] , label =  2040.0
# prediction =  [1914.9252] , label =  2009.0
# prediction =  [1789.171] , label =  2004.0
# prediction =  [2110.904] , label =  1995.0
# prediction =  [1723.615] , label =  1990.0
# prediction =  [1809.6852] , label =  1983.0
# prediction =  [1763.3857] , label =  1962.0
# prediction =  [2078.0156] , label =  1944.0
# prediction =  [1644.9705] , label =  1935.0
# prediction =  [1658.5667] , label =  1915.0
# prediction =  [2226.1284] , label =  1911.0
# prediction =  [1684.4036] , label =  1908.0
# prediction =  [1790.447] , label =  1908.0
# prediction =  [1604.2876] , label =  1883.0
# prediction =  [1674.8114] , label =  1882.0
# prediction =  [1746.2075] , label =  1860.0
# prediction =  [1712.1571] , label =  1824.0
# prediction =  [1695.4343] , label =  1815.0
# prediction =  [1955.2744] , label =  1811.0
# prediction =  [1945.4329] , label =  1808.0
# prediction =  [1754.2766] , label =  1807.0
# prediction =  [1947.6919] , label =  1794.0
# prediction =  [1706.6975] , label =  1790.0
# prediction =  [1647.6147] , label =  1770.0
# prediction =  [1674.2593] , label =  1768.0
# prediction =  [1670.2328] , label =  1758.0
# prediction =  [1661.191] , label =  1742.0
# prediction =  [2091.1492] , label =  1740.0
# prediction =  [2068.419] , label =  1739.0
# prediction =  [2083.444] , label =  1730.0
# prediction =  [2052.937] , label =  1724.0
# prediction =  [2038.7461] , label =  1722.0
# prediction =  [1971.2314] , label =  1715.0
# prediction =  [2027.7102] , label =  1715.0
# prediction =  [1944.7341] , label =  1712.0
# prediction =  [1901.9988] , label =  1710.0
# prediction =  [1898.5405] , label =  1689.0
# prediction =  [1952.786] , label =  1687.0
# prediction =  [1858.7185] , label =  1686.0
# prediction =  [1797.7479] , label =  1677.0
# prediction =  [1802.6127] , label =  1671.0
# prediction =  [1803.3551] , label =  1650.0
# prediction =  [1853.478] , label =  1642.0
# prediction =  [1744.3784] , label =  1638.0
# prediction =  [1872.15] , label =  1621.0
# prediction =  [1804.0568] , label =  1611.0
# prediction =  [1830.8413] , label =  1596.0
# prediction =  [1741.9927] , label =  1569.0
# prediction =  [1882.9908] , label =  1567.0
# prediction =  [1842.7178] , label =  1558.0
# prediction =  [1663.5017] , label =  1549.0
# prediction =  [1823.0358] , label =  1546.0
# prediction =  [1781.5759] , label =  1541.0
# prediction =  [1874.7661] , label =  1534.0
# prediction =  [1766.0768] , label =  1521.0
# prediction =  [1740.8031] , label =  1498.0
# prediction =  [1813.9944] , label =  1497.0
# prediction =  [1715.1787] , label =  1484.0
# prediction =  [1580.4636] , label =  1471.0
# prediction =  [1650.7] , label =  1463.0
# prediction =  [1642.8582] , label =  1451.0
# prediction =  [1576.9634] , label =  1450.0
# prediction =  [1642.328] , label =  1445.0
# prediction =  [1658.4619] , label =  1441.0
# prediction =  [1668.9504] , label =  1425.0
# prediction =  [1634.0957] , label =  1399.0
# prediction =  [1636.6473] , label =  1393.0
